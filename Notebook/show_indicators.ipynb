# %% [markdown]
# ### Notebook para ler os dados de indicadores consolidados e mostrar abaixo

# %%
from pyspark.sql import functions as f

spark

tabela_final_local = "s3://datalake-ricardo-pucminas-808833868807/output/indicadores_consolidados"
# tabela_final_local = "../output/indicadores_consolidados"

def read_parquet(local):
    dataset = (
        spark
        .read
        .parquet(local)
    )
    return dataset


tabela_indicadores = read_parquet(tabela_final_local)

tabela_indicadores.show(20000)
# Out:
# VBox()
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1</td><td>application_1668456932827_0004</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-124-165.ec2.internal:20888/proxy/application_1668456932827_0004/" class="emr-proxy-link" emr-resource="j-3K6G0YPJEAG82
# " application-id="application_1668456932827_0004">Link</a></td><td><a target="_blank" href="http://ip-192-168-108-67.ec2.internal:8042/node/containerlogs/container_1668456932827_0004_01_000001/livy" >Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ...
